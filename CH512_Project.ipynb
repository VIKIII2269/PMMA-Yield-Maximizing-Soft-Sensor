# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('data.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
X
# Out:
# array([[2.44310666e-02, 3.46867279e+02, 3.31874633e+02, ...,
#         1.02878163e+00, 2.93200000e+02, 3.50014529e+02],
#        [2.50162993e-02, 3.42013221e+02, 3.34982669e+02, ...,
#         1.00329503e+00, 2.93200000e+02, 3.49904450e+02],
#        [2.53664919e-02, 3.44491549e+02, 3.32124375e+02, ...,
#         9.87497359e-01, 2.93200000e+02, 3.50088297e+02],
#        ...,
#        [2.47476565e-02, 3.49774604e+02, 3.28797109e+02, ...,
#         1.01380080e+00, 2.93200000e+02, 3.49964777e+02],
#        [2.49302356e-02, 3.57088832e+02, 3.30851358e+02, ...,
#         1.00447033e+00, 2.93200000e+02, 3.50021956e+02],
#        [2.49185950e-02, 3.47881562e+02, 3.30365879e+02, ...,
#         1.00634565e+00, 2.93200000e+02, 3.49977713e+02]])

# %% [markdown]
# #Removing Outliers

# %%
from scipy.stats import zscore
#Z-score tells us how many standard deviations above or below the mean a datapoint lies. It assumes that the datapoints follow a gaussian distribution[1].

#From the above normal distribtion figure we can we that:

#68% of the data lies within 1 standard deviation.
#95% of the data lies within 2 standard deviations.
#99.7% of the data lies within 3 standard deviations.
#Since majority of the datapoints (99.7%) lie within 3 standard deviations above or below the mean, any Z-score more than +3 or any Z-score less than -3 is considered as an outlier.
# Calculate Z-scores for each data point
z_scores = zscore(X)
# Define a threshold for identifying outliers
threshold = 3
# Identify outliers
outliers = (z_scores > threshold) | (z_scores < -threshold)

# %% [markdown]
# ##Feature Selection

# %%
from sklearn.feature_selection import RFE
estimator=LinearRegression()
sel = RFE(estimator=estimator,n_features_to_select=2, step=1)
sel = sel.fit_transform(X, y)
print (sel)
# Out:
# [[0.02443107 1.02878163]
#  [0.0250163  1.00329503]
#  [0.02536649 0.98749736]
#  ...
#  [0.02474766 1.0138008 ]
#  [0.02493024 1.00447033]
#  [0.0249186  1.00634565]]

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(sel, y, test_size = 0.3, random_state = 1)
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %% [markdown]
# ##Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

model = LinearRegression()
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Calculate AIC
n = len(y_train)
p = X_train.shape[1] + 1  # Number of parameters (including intercept)
aic = n * np.log(mse) + 2 * p

print(f"AIC: {aic}")

# Print the coefficients and intercept
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
r2_score(y_test,y_pred)
# Out:
# Mean Squared Error: 3.726761654178907e-05
# AIC: -61178.314785823335
# Coefficients: [223.69190701   6.23043635]
# Intercept: -5.800010571225538
# 0.7590920922526123

# %% [markdown]
# #Visualising results for multiple subsets

# %%
import matplotlib.pyplot as plt

# Plot the actual test cases vs. the predictions
plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red')  # Plot the y=x line for reference
plt.title('Actual vs. Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %% [markdown]
# ##Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

# Fit the polynomial regression model
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Predict on the test set
y_pred1 = model.predict(X_test_poly)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
n = len(y_train)
p = X_train.shape[1] + 1  # Number of parameters (including intercept)
aic = n * np.log(mse) + 2 * p

print(f"AIC: {aic}")


r2_score(y_test,y_pred)
# Out:
# Mean Squared Error: 3.726761654178907e-05
# AIC: -42823.02035007634
# 0.7590920922526123

# %%
import matplotlib.pyplot as plt

# Plot the actual test cases vs. the predictions
plt.scatter(y_test, y_pred1, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')  # Plot the y=x line for reference
plt.title('Actual vs. Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %% [markdown]
# ## Applying PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components =  4)#max accuracy point
X_train1 = pca.fit_transform(X_train1)
X_test1 = pca.transform(X_test1)

# %% [markdown]
# ## Training the Linear Regression model on the Training set

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

model = LinearRegression()
model.fit(X_train1, y_train)

# Predict on the test set
y_pred = model.predict(X_test1)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

# Print the coefficients and intercept
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)

n = len(y_train)
p = X_train.shape[1] + 1  # Number of parameters (including intercept)
aic = n * np.log(mse) + 2 * p

print(f"AIC: {aic}")

r2_score(y_test,y_pred)
# Out:
# Mean Squared Error: 2.1107854969007497e-05
# Coefficients: [ 1.02802240e+02 -3.93313771e-05 -8.84973937e-06 -5.25112382e-07
#   3.35969893e+00  1.85848710e-03 -6.35570582e-02]
# Intercept: 21.81895893315459
# AIC: -45210.63431605374
# 0.8635531421249624

# %%
import matplotlib.pyplot as plt

# Plot the actual test cases vs. the predictions
plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')  # Plot the y=x line for reference
plt.title('Actual vs. Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %% [markdown]
# #Polynomial Regression on PCA

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

poly = PolynomialFeatures(degree=3)
X_train_poly = poly.fit_transform(X_train1)
X_test_poly = poly.transform(X_test1)

# Fit the polynomial regression model
model = LinearRegression()
model.fit(X_train_poly, y_train)

# Predict on the test set
y_pred1 = model.predict(X_test_poly)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
n = len(y_train)
p = X_train.shape[1] + 1  # Number of parameters (including intercept)
aic = n * np.log(mse) + 2 * p

print(f"AIC: {aic}")


r2_score(y_test,y_pred1)
# Out:
# Mean Squared Error: 2.1107854969007497e-05
# AIC: -45210.63431605374
# 0.8685903868061529

# %% [markdown]
# ## Visualising the Regression results

# %%
import matplotlib.pyplot as plt

# Plot the actual test cases vs. the predictions
plt.scatter(y_test, y_pred1, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')  # Plot the y=x line for reference
plt.title('Actual vs. Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %% [markdown]
# #Using Lasso Techinique

# %%
from sklearn.linear_model import Lasso


 # Regularization strength
model = Lasso(alpha=0.01)
model.fit(X_train1, y_train1)

# Predict on the test set
y_pred = model.predict(X_test1)

# Evaluate the model
mse = mean_squared_error(y_test1, y_pred)
print(f"Mean Squared Error: {mse}")

n = len(y_train1)
p = X_train1.shape[1] + 1  # Number of parameters (including intercept)
aic = n * np.log(mse) + 2 * p

print(f"AIC: {aic}")


r2_score(y_test1,y_pred)
# Out:
# Mean Squared Error: 0.00015475773303572454
# AIC: -36833.32864128485
# -0.0003956553422073128

# %%
import matplotlib.pyplot as plt

# Plot the actual test cases vs. the predictions
plt.scatter(y_test1, y_pred, color='blue')
plt.plot([min(y_test1), max(y_test1)], [min(y_test1), max(y_test1)], color='red', linestyle='--')  # Plot the y=x line for reference
plt.title('Actual vs. Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %% [markdown]
# ## Part 2 - Building the ANN single layered

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import tensorflow as tf
from tensorflow import keras


# Define the ANN model
model = keras.Sequential([
    keras.layers.Dense(5, activation='relu'),
    keras.layers.Dense(1, activation='linear')
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))

# Evaluate the model
loss, mae, mse = model.evaluate(X_test, y_test)
print(f'Test Mean Squared Error: {mse}')
# Out:
# Epoch 1/100
# 132/132 [==============================] - 1s 3ms/step - loss: 31.6328 - mae: 5.6119 - mse: 31.6328 - val_loss: 28.1324 - val_mae: 5.2832 - val_mse: 28.1324
# Epoch 2/100
# 132/132 [==============================] - 0s 2ms/step - loss: 24.7229 - mae: 4.9316 - mse: 24.7229 - val_loss: 20.8061 - val_mae: 4.5015 - val_mse: 20.8061
# Epoch 3/100
# 132/132 [==============================] - 0s 2ms/step - loss: 17.5700 - mae: 4.0984 - mse: 17.5700 - val_loss: 13.8590 - val_mae: 3.5858 - val_mse: 13.8590
# Epoch 4/100
# 132/132 [==============================] - 0s 2ms/step - loss: 11.4490 - mae: 3.2045 - mse: 11.4490 - val_loss: 8.7331 - val_mae: 2.7308 - val_mse: 8.7331
# Epoch 5/100
# 132/132 [==============================] - 0s 3ms/step - loss: 7.3252 - mae: 2.4790 - mse: 7.3252 - val_loss: 5.8033 - val_mae: 2.1750 - val_mse: 5.8033
# Epoch 6/100
# 132/132 [==============================] - 0s 3ms/step - loss: 4.9928 - mae: 2.0132 - mse: 4.9928 - val_loss: 4.2322 - val_mae: 1.8362 - val_mse: 4.2322
# Epoch 7/100
# 132/132 [==============================] - 0s 3ms/step - loss: 3.6194 - mae: 1.7021 - mse: 3.6194 - val_loss: 3.1909 - val_mae: 1.5760 - val_mse: 3.1909
# Epoch 8/100
# 132/132 [==============================] - 0s 2ms/step - loss: 2.6258 - mae: 1.4387 - mse: 2.6258 - val_loss: 2.3228 - val_mae: 1.3233 - val_mse: 2.3228
# Epoch 9/100
# 132/132 [==============================] - 0s 2ms/step - loss: 1.8074 - mae: 1.1719 - mse: 1.8074 - val_loss: 1.5794 - val_mae: 1.0597 - val_mse: 1.5794
# Epoch 10/100
# 132/132 [==============================] - 0s 3ms/step - loss: 1.1613 - mae: 0.9089 - mse: 1.1613 - val_loss: 1.0097 - val_mae: 0.8144 - val_mse: 1.0097
# Epoch 11/100
# 132/132 [==============================] - 0s 3ms/step - loss: 0.7238 - mae: 0.6841 - mse: 0.7238 - val_loss: 0.6479 - val_mae: 0.6158 - val_mse: 0.6479
# Epoch 12/100
# 132/132 [==============================] - 0s 3ms/step - loss: 0.4655 - mae: 0.5079 - mse: 0.4655 - val_loss: 0.4422 - val_mae: 0.4714 - val_mse: 0.4422
# Epoch 13/100
# 132/132 [==============================] - 0s 3ms/step - loss: 0.3244 - mae: 0.3946 - mse: 0.3244 - val_loss: 0.3207 - val_mae: 0.3861 - val_mse: 0.3207
# Epoch 14/100
# 132/132 [==============================] - 0s 2ms/step - loss: 0
100
# 132/132 [==============================] - 0s 3ms/step - loss: 5.2363e-05 - mae: 0.0057 - mse: 5.2363e-05 - val_loss: 4.4708e-05 - val_mae: 0.0052 - val_mse: 4.4708e-05
# Epoch 93/100
# 132/132 [==============================] - 0s 3ms/step - loss: 4.5245e-05 - mae: 0.0053 - mse: 4.5245e-05 - val_loss: 5.3043e-05 - val_mae: 0.0058 - val_mse: 5.3043e-05
# Epoch 94/100
# 132/132 [==============================] - 1s 4ms/step - loss: 4.6131e-05 - mae: 0.0053 - mse: 4.6131e-05 - val_loss: 3.9725e-05 - val_mae: 0.0050 - val_mse: 3.9725e-05
# Epoch 95/100
# 132/132 [==============================] - 1s 4ms/step - loss: 4.2416e-05 - mae: 0.0051 - mse: 4.2416e-05 - val_loss: 4.3701e-05 - val_mae: 0.0052 - val_mse: 4.3701e-05
# Epoch 96/100
# 132/132 [==============================] - 1s 4ms/step - loss: 4.8095e-05 - mae: 0.0054 - mse: 4.8095e-05 - val_loss: 6.0678e-05 - val_mae: 0.0061 - val_mse: 6.0678e-05
# Epoch 97/100
# 132/132 [==============================] - 0s 3ms/step - loss: 4.6267e-05 - mae: 0.0054 - mse: 4.6267e-05 - val_loss: 3.9177e-05 - val_mae: 0.0050 - val_mse: 3.9177e-05
# Epoch 98/100
# 132/132 [==============================] - 0s 3ms/step - loss: 4.2149e-05 - mae: 0.0051 - mse: 4.2149e-05 - val_loss: 5.6257e-05 - val_mae: 0.0060 - val_mse: 5.6257e-05
# Epoch 99/100
# 132/132 [==============================] - 0s 2ms/step - loss: 4.8551e-05 - mae: 0.0055 - mse: 4.8551e-05 - val_loss: 4.3840e-05 - val_mae: 0.0052 - val_mse: 4.3840e-05
# Epoch 100/100
# 132/132 [==============================] - 0s 3ms/step - loss: 4.7068e-05 - mae: 0.0054 - mse: 4.7068e-05 - val_loss: 4.0238e-05 - val_mae: 0.0050 - val_mse: 4.0238e-05
# 57/57 [==============================] - 0s 1ms/step - loss: 4.0238e-05 - mae: 0.0050 - mse: 4.0238e-05
# Test Mean Squared Error: 4.023849396617152e-05

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import r2_score
n = len(y_train)
p = X_train.shape[1] + 1  # Number of parameters (including intercept)
aic = n * np.log(mse) + 2 * p

print(f"AIC: {aic}")

r2_score(y_test, y_pred)
# Out:
# 57/57 [==============================] - 0s 2ms/step
# AIC: -42500.88312847685
# 0.7398871354836924

# %%
import matplotlib.pyplot as plt

# Plot the actual test cases vs. the predictions
plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')  # Plot the y=x line for reference
plt.title('Actual vs. Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %% [markdown]
# ## Implementing ANN for multiple hidden layers

# %%
# Define the ANN model
model2 = keras.Sequential([
    keras.layers.Dense(5, activation='relu'),keras.layers.Dense(10, activation='relu'),keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='linear')
])

# Compile the model
model2.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae', 'mse'])

# Train the model
history2 = model2.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))

# Evaluate the model
loss, mae, mse = model.evaluate(X_test, y_test)
print(f'Test Mean Squared Error: {mse}')
# Out:
# Epoch 1/100
# 132/132 [==============================] - 2s 6ms/step - loss: 20.8362 - mae: 4.3346 - mse: 20.8362 - val_loss: 6.0523 - val_mae: 2.1529 - val_mse: 6.0523
# Epoch 2/100
# 132/132 [==============================] - 0s 4ms/step - loss: 3.7280 - mae: 1.6349 - mse: 3.7280 - val_loss: 2.0926 - val_mae: 1.2187 - val_mse: 2.0926
# Epoch 3/100
# 132/132 [==============================] - 1s 4ms/step - loss: 1.0128 - mae: 0.7969 - mse: 1.0128 - val_loss: 0.4937 - val_mae: 0.5115 - val_mse: 0.4937
# Epoch 4/100
# 132/132 [==============================] - 1s 4ms/step - loss: 0.2477 - mae: 0.3724 - mse: 0.2477 - val_loss: 0.1559 - val_mae: 0.2931 - val_mse: 0.1559
# Epoch 5/100
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0931 - mae: 0.2273 - mse: 0.0931 - val_loss: 0.0724 - val_mae: 0.2017 - val_mse: 0.0724
# Epoch 6/100
# 132/132 [==============================] - 0s 2ms/step - loss: 0.
# Epoch 95/100
# 132/132 [==============================] - 0s 3ms/step - loss: 5.5513e-05 - mae: 0.0059 - mse: 5.5513e-05 - val_loss: 1.4426e-04 - val_mae: 0.0088 - val_mse: 1.4426e-04
# Epoch 96/100
# 132/132 [==============================] - 1s 4ms/step - loss: 9.2517e-05 - mae: 0.0075 - mse: 9.2517e-05 - val_loss: 2.1416e-04 - val_mae: 0.0119 - val_mse: 2.1416e-04
# Epoch 97/100
# 132/132 [==============================] - 0s 4ms/step - loss: 1.1432e-04 - mae: 0.0086 - mse: 1.1432e-04 - val_loss: 1.0116e-04 - val_mae: 0.0066 - val_mse: 1.0116e-04
# Epoch 98/100
# 132/132 [==============================] - 1s 4ms/step - loss: 1.9482e-04 - mae: 0.0107 - mse: 1.9482e-04 - val_loss: 1.4535e-04 - val_mae: 0.0088 - val_mse: 1.4535e-04
# Epoch 99/100
# 132/132 [==============================] - 1s 4ms/step - loss: 5.9624e-05 - mae: 0.0061 - mse: 5.9624e-05 - val_loss: 8.7482e-05 - val_mae: 0.0062 - val_mse: 8.7482e-05
# Epoch 100/100
# 132/132 [==============================] - 1s 4ms/step - loss: 6.2594e-05 - mae: 0.0063 - mse: 6.2594e-05 - val_loss: 7.2889e-05 - val_mae: 0.0053 - val_mse: 7.2889e-05
# 57/57 [==============================] - 0s 2ms/step - loss: 4.0238e-05 - mae: 0.0050 - mse: 4.0238e-05
# Test Mean Squared Error: 4.023849396617152e-05

# %%
y_pred = model2.predict(X_test)
from sklearn.metrics import r2_score
n = len(y_train)
p = X_train.shape[1] + 1  # Number of parameters (including intercept)
aic = n * np.log(mse) + 2 * p

print(f"AIC: {aic}")


r2_score(y_test, y_pred)
# Out:
# 57/57 [==============================] - 0s 2ms/step
# AIC: -42500.88312847685
# 0.5288274281180687

# %%
import matplotlib.pyplot as plt

# Plot the actual test cases vs. the predictions
plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')  # Plot the y=x line for reference
plt.title('Actual vs. Predicted')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %% [markdown]
# ##KNN

# %%
from sklearn.neighbors import NearestNeighbors

X_train, X_val, y_train, y_val = train_test_split(selector, y, test_size=0.3, random_state=42)

# Create a database including the training data
training_data = (X_train, y_train)

#  For each validation data point, use k-NN to find the k nearest neighbors
def knn_search(x_val, k):
    knn = NearestNeighbors(n_neighbors=k)
    knn.fit(X_train)
    distances, indices = knn.kneighbors([x_val])
    return indices[0]

# Build a local just-in-time neural network model using the k-NN search results
def build_local_model(X_train, y_train, indices):
    local_X_train = X_train[indices]
    local_y_train = y_train[indices]

    # Define and compile the local neural network model
    local_model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(10, activation='relu', input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(1, activation=None)
    ])
    local_model.compile(optimizer='adam', loss='mean_squared_error')

    # Train the local model
    local_model.fit(local_X_train, local_y_train, epochs=5, batch_size=128)

    return local_model

# Use the local model to make predictions for the current validation input
def predict_with_local_model(local_model, x_val):
    return local_model.predict(np.array([x_val]))

# Repeat the process for all validation data points
predictions = []
for x_val in X_val:
    indices = knn_search(x_val, k=3)  # Change k value as needed
    local_model = build_local_model(X_train, y_train, indices)
    prediction = predict_with_local_model(local_model, x_val)
    predictions.append(prediction)

# Convert predictions to numpy array
predictions = np.array(predictions)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 2s 2s/step - loss: 2.7859
# Epoch 2/5
# 1/1 [==============================] - 0s 27ms/step - loss: 2.7750
# Epoch 3/5
# 1/1 [==============================] - 0s 20ms/step - loss: 2.7641
# Epoch 4/5
# 1/1 [==============================] - 0s 17ms/step - loss: 2.7532
# Epoch 5/5
# 1/1 [==============================] - 0s 16ms/step - loss: 2.7424
# 1/1 [==============================] - 0s 116ms/step
# Epoch 1/5
# 1/1 [==============================] - 1s 1s/step - loss: 0.4659
# Epoch 2/5
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4647
# Epoch 3/5
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4637
# Epoch 4/5
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4629
# Epoch 5/5
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4622
# 1/1 [==============================] - 0s 81ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-244-29e957441170> in <cell line: 38>()
#      38 for x_val in X_val:
#      39     indices = knn_search(x_val, k=3)  # Change k value as needed
# ---> 40     local_model = build_local_model(X_train, y_train, indices)
#      41     prediction = predict_with_local_model(local_model, x_val)
#      42     predictions.append(prediction)
#
# <ipython-input-244-29e957441170> in build_local_model(X_train, y_train, indices)
#      19
#      20     # Define and compile the local neural network model
# ---> 21     local_model = tf.keras.models.Sequential([
#      22         tf.keras.layers.Dense(10, activation='relu', input_shape=(X_train.shape[1],)),
#      23         tf.keras.layers.Dense(1, activation=None)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     202     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203     try:
# --> 204       result = method(self, *args, **kwargs)
#     205     finally:
#     206       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/sequential.py in __init__(self, layers, name)
#     133                 layers = [layers]
#     134             for layer in layers:
# --> 135                 self.add(layer)
#     136
#     137     @property
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     202     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203     try:
# --> 204       result = method(self, *args, **kwargs)
#     205     finally:
#     206       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/sequential.py in add(self, layer)
#     227             # If the model is being built continuously on top of an input layer:
#     228             # refresh its output.
# --> 229             output_tensor = layer(self.outputs[0])
#     230             if len(tf.nest.flatten(output_tensor)) != 1:
#     231                 raise ValueError(SINGLE_LAYER_OUTPUT_ERROR_MSG)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1061             self, inputs, args, kwargs, input_list
#    1062         ):
# -> 1063             return self._functional_construction_call(
#    1064                 inputs, args, kwargs, input_list
#    1065             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    2591             # shape.
#    2592             try:
# -> 2593                 outputs = self._keras_tensor_symbolic_call(
#    2594                     inputs, input_masks, args, kwargs
#    2595                 )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in _keras_tensor_symbolic_call(self, inputs, input_masks, args, kwargs)
#    2437             )
#    2438         else:
# -> 2439             return self._infer_output_signature(
#    2440                 inputs, args, kwargs, input_masks
#    2441             )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in _infer_output_signature(self, inputs, args, kwargs, input_masks)
#    2494                     # TODO(kaftan): do we maybe_build here, or have we already
#    2495                     # done it?
# -> 2496                     self._maybe_build(inputs)
#    2497                     inputs = self._maybe_cast_inputs(inputs)
#    2498                     outputs = call_fn(inputs, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in _maybe_build(self, inputs)
#    3025                 # later pollute any eager operations.
#    3026                 with tf_utils.maybe_init_scope(self):
# -> 3027                     self.build(input_shapes)
#    3028             # We must set also ensure that the layer is marked as built, and the
#    3029             # build shape is stored since user defined build functions may not
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py in build(self, input_shape)
#     162         )
#     163         if self.use_bias:
# --> 164             self.bias = self.add_weight(
#     165                 "bias",
#     166                 shape=[
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     710             getter = functools.partial(getter, layout=layout)
#     711
# --> 712         variable = self._add_variable_with_custom_getter(
#     713             name=name,
#     714             shape=shape,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/trackable/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     490         # "best effort" to set the initializer with the highest restore UID.
#     491         initializer = checkpoint_initializer
# --> 492     new_variable = getter(
#     493         name=name,
#     494         shape=shape,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner, layout, experimental_enable_variable_lifting)
#     125         initializer, dtype, shape, layout
#     126     )
# --> 127     variable_shape = tf.TensorShape(shape)
#     128
#     129     if use_resource is None:
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/tensor_shape.py in __init__(self, dims)
#     828     """
#     829     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 830       self._dims = tuple(as_dimension(d).value for d in dims)
#     831     elif dims is None:
#     832       self._dims = None
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/tensor_shape.py in <genexpr>(.0)
#     828     """
#     829     if isinstance(dims, (tuple, list)):  # Most common case.
# --> 830       self._dims = tuple(as_dimension(d).value for d in dims)
#     831     elif dims is None:
#     832       self._dims = None
#
# KeyboardInterrupt:

# %%
y_pred = local_model.predict(X_val)
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 57/57 [==============================] - 0s 1ms/step
# -234711.3880717622
